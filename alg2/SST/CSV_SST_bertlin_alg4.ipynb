# %%
sst_dataset = {}
for split in ["train", "dev", "test"]:
    URL = f"https://raw.githubusercontent.com/successar/instance_attributions_NLP/master/Datasets/SST/data/{split}.jsonl"
    import urllib.request, json 
    with urllib.request.urlopen(URL) as url:
        data = url.read().decode()
        data = [json.loads(line) for line in data.strip().split("\n")]
        sst_dataset[split] = data

# %%
import numpy as np
from tqdm import tqdm

# %%
ls
# Out:
# CSV_SST_LR_alg4.csv                    diffs_SST_LR_I100_D1_.npy
# CSV_SST_LR_alg4.ipynb                  diffs_SST_bertT_I100_D1.npy
# CSV_SST_bertlin_alg4.csv               iterations_SST_LR_I100_D1.npy
# CSV_SST_bertlin_alg4.ipynb             iterations_SST_LR_I100_D1_.npy
# CSV_emo_LR_alg4.ipynb                  iterations_SST_bertT_I100_D1.npy
# NT_app_k_SST_LR_I100_D1.npy            new_predictions_SST_LR_I100_D1.npy
# NT_app_k_SST_LR_I100_D1_.npy           new_predictions_SST_LR_I100_D1_.npy
# NT_app_k_SST_bertT_I100_D1.npy         new_predictions_SST_bertT_I100_D1.npy
# Recursive_IP.py                        order_SST_LR_I100_D1.npy
# Recursive_IP_emotion.ipynb             order_SST_LR_I100_D1_.npy
# Recursive_IP_sst.ipynb                 order_SST_bertT_I100_D1.npy
# SST_LR.ipynb                           test_feature_SST.npy
# SST_bertlin.ipynb                      test_label_SST.npy
# Untitled.ipynb                         train_feature_SST.npy
# diffs_SST_LR_I100_D1.npy               train_label_SST.npy

# %%
app_k = np.load("NT_app_k_SST_bertT_I100_D1.npy", allow_pickle=True)
pred = np.load("/Users/eciel/Desktop/y3s2_sum/orf/summer/privacy_methods/BERT/Bert_SST/Bert_linear_SST/old_predictions.npy")
app_k_nonon=[]
for i in range(app_k.shape[0]):
    print(app_k[i])
    if app_k[i] == None:
        app_k_nonon.append(6920)
    else:
        app_k_nonon.append(app_k[i])
# Out:
# None
# 74
# None
# 248
# 384
# None
# None
# 23
# None
# 8
# 3572
# None
# None
# 955
# 13
# 79
# 130
# 323
# None
# None
# 9
# None
# 127
# 628
# None
# None
# 283
# 129
# 493
# 21
# None
# 868
# 88
# 1348
# 152
# 79
# 401
# 11
# 210
# 42
# None
# 27
# 47
# 862
# 43
# None
# None
# 339
# None
# 240
# 1396
# 332
# 669
# 178
# None
# 3
# 92
# 60
# 11
# 372
# None
# None
# 132
# None
# None
# None
# 1094
# 20
# None
# 594
# 29
# None
# 579
# None
# 71
# None
# 133
# None
# 1064
# 17
# None
# None
# 458
# 347
# 186
# 223
# 254
# 54
# None
# None
# 226
# 75
# None
# 53
# 13
# 286
# None
# None
# 1184
# 1496
# 421
# 90
# 18
# 1263
# None
# None
# 864
# None
# None
# 629
# 33
# 2
# 863
# 32
# 356
# 84
# 156
# 22
# 690
# None
# 1116
# 240
# 7
# 541
# 269
# 151
# 143
# None
# None
# 1342
# None
# 708
# 165
# 134
# 86
# 271
# 3
# 11
# 91
# 509
# 9
# 778
# None
# None
# 858
# 762
# None
# None
# None
#        618, 673, 640, 752,  28, 139, 379, 399, 505, 546, 734, 534, 351,
#        531, 222, 382, 454, 568, 206, 123, 277, 500, 484, 526, 368, 832,
#        865, 813, 152, 738, 451,  72, 641, 659, 517,  69, 323, 186, 227,
#        539,  23, 748, 109, 854, 695, 238, 790, 560, 689,  52, 804, 456,
#        377, 843, 182, 727, 118, 577, 559, 131, 328, 714, 643, 678, 346,
#        426, 165, 852, 314, 601, 145, 622, 430, 141, 782, 670, 413, 255,
#        318, 599, 465, 747, 805, 397, 347, 173, 144,  43, 112, 106,  31,
#        823, 219, 779, 449, 285, 633, 369, 214, 578, 267, 775, 638,  13,
#        417, 470, 418, 415, 355, 498, 476, 356, 283, 411, 768, 744, 175,
#        198, 359, 820, 334, 509,  78, 709, 249,  66, 665, 167, 120, 250,
#        261, 848, 424, 610,  98, 398, 309, 817, 213, 795, 808, 499, 317,
#        103, 855, 654, 195, 270, 129, 606,  33,  50, 463,  99,  10, 758,
#        755, 796, 764, 839, 856, 743, 842, 707, 715, 811, 849, 836, 845,
#        745, 756,   0, 699, 188, 187, 183, 180, 179, 176, 172, 159, 156,
#        155, 154, 149, 148, 147, 146, 143, 142, 194, 130, 196, 203, 251,
#        248, 243, 241, 237, 236, 235, 232, 229, 226, 223, 221, 212, 211,
#        209, 208, 207, 197, 252, 128, 119,  54,  48,  46,  45,  40,  30,
#         25,  24,  21,  19,  18,  12,  11,   8,   6,   5,   2,  60, 127,
#         61,  64, 108, 107, 105, 104,  97,  96,  92,  89,  88,  81,  80,
#         77,  75,  73,  71,  68,  65,  63, 701, 254, 260, 478, 473, 461,
#        450, 438, 433, 431, 429, 428, 423, 419, 414, 404, 402, 400, 391,
#        390, 485, 389, 491, 525, 697, 682, 679, 660, 647, 627, 626, 625,
#        620, 616, 609, 591, 589, 582, 567, 557, 551, 503, 259, 388, 384,
#        297, 296, 293, 290, 289, 288, 287, 286, 284, 278, 275, 273, 272,
#        271, 269, 268, 262, 301, 387, 302, 305, 383, 380, 374, 373, 363,
#        360, 357, 349, 341, 339, 337, 333, 332, 329, 316, 313, 312, 304,
#        871])

# %%
order_lis = np.load("order_SST_bertT_I100_D1.npy", allow_pickle=True)

# %%
header = ["test_movie_id", "test_movie_review_text", "old_prediction", "right_prediction", "k", "successful_flip"]
for i in range(6920):
    header.append("train_example_" + str(i+1))

# %%
new_predictions = np.load("new_predictions_SST_bertT_I100_D1.npy", allow_pickle=True)

# %%
data = []
for test_movie_id in sort_dev_k:
    k = app_k[test_movie_id]
    item = sst_dataset["dev"][test_movie_id]
    
    test_point = []
    # id
    test_point.append(test_movie_id)
    # test_movie_review_text
    test_point.append("label: " + str(item['label']) + "  doc: " + str(item['document']))
    test_point.append(pred[test_movie_id].item())
    test_point.append(np.round(pred[test_movie_id].item()) == item['label'])
    # k
    test_point.append(str(k))
    if k == None:
        data.append(test_point)
        continue
    test_point.append(np.round(new_predictions[test_movie_id]) != np.round(pred[test_movie_id].item()))
    
    top_k_index = order_lis[test_movie_id]
    print("k", k)
    print("top_k_index", len(top_k_index))
    
    # training examples
    for idx in top_k_index:
        item = sst_dataset["train"][idx]
        test_point.append("id: " + str(idx) + "  label: " + str(item['label']) + "  doc: " + str(item['document']))
    data.append(test_point)
# Out:
# k 1
# top_k_index 1
# k 1
# top_k_index 1
# k 1
# top_k_index 1
# k 1
# top_k_index 1
# k 1
# top_k_index 1
# k 1
# top_k_index 1
# k 1
# top_k_index 1
# k 1
# top_k_index 1
# k 2
# top_k_index 2
# k 2
# top_k_index 2
# k 2
# top_k_index 2
# k 2
# top_k_index 2
# k 3
# top_k_index 3
# k 3
# top_k_index 3
# k 3
# top_k_index 3
# k 3
# top_k_index 3
# k 3
# top_k_index 3
# k 3
# top_k_index 3
# k 4
# top_k_index 4
# k 4
# top_k_index 4
# k 4
# top_k_index 4
# k 4
# top_k_index 4
# k 4
# top_k_index 4
# k 5
# top_k_index 5
# k 5
# top_k_index 5
# k 5
# top_k_index 5
# k 6
# top_k_index 6
# k 6
# top_k_index 6
# k 6
# top_k_index 6
# k 7
# top_k_index 7
# k 7
# top_k_index 7
# k 7
# top_k_index 7
# k 7
# top_k_index 7
# k 7
# top_k_index 7
# k 7
# top_k_index 7
# k 7
# top_k_index 7
# k 8
# top_k_index 8
# k 8
# top_k_index 8
# k 9
# top_k_index 9
# k 9
# top_k_index 9
# k 9
# top_k_index 9
# k 9
# top_k_index 9
# k 9
# top_k_index 9
# k 9
# top_k_index 9
# k 10
# top_k_index 10
# k 11
# top_k_index 11
# k 11
# top_k_index 11
# k 11
# top_k_index 11
# k 11
# top_k_index 11
# k 11
# top_k_index 11
# k 12
# top_k_index 12
# k 12
# top_k_index 12
# k 12
# top_k_index 12
# k 12
# top_k_index 12
# k 13
# top_k_index 13
# k 13
# top_k_index 13
# k 13
# top_k_index 13
# k 13
# top_k_index 13
# k 13
# top_k_index 13
# k 13
# top_k_index 13
# k 13
# top_k_index 13
# k 14
# top_k_index 14
# k 14
# top_k_index 14
# k 14
# top_k_index 14
# k 14
# top_k_index 14
# k 14
# top_k_index 14
# k 15
# top_k_index 15
# k 15
# top_k_index 15
# k 16
# top_k_index 16
# k 16
# top_k_index 16
# k 16
# top_k_index 16
# k 17
# top_k_index 17
# k 17
# top_k_index 17
# k 17
# top_k_index 17
# k 17
# top_k_index 17
# k 18
# top_k_index 18
# k 18
# top_k_index 18
# k 18
# top_k_index 18
# k 18
# top_k_index 18
# k 18
# top_k_index 18
# k 18
# top_k_index 18
# k 18
# top_k_index 18
# k 20
# top_k_index 20
# k 20
# top_k_index 20
# k 20
# top_k_index 20
# k 20
# top_k_index 20
# k 20
# top_k_index 20
# k 21
# top_k_index 21
# k 21
# top_k_index 21
# k 21
# top_k_index 21
# k 21
# top_k_index 21
# k 22
# top_k_index 22
# k 22
# top_k_index 22
# k 22
# top_k_index 22
# k 22
# top_k_index 22
# k 22
# top_k_index 22
# k 22
# top_k_index 22
# k 23
# top_k_index 23
# k 23
# top_k_index 23
# k 23
# top_k_index 23
# k 23
# top_k_index 23
# k 23
# top_k_index 23
# k 24
# top_k_index 24
# k 24
# top_k_index 24
# k 25
# top_k_index 25
# k 25
# top_k_index 25
# k 25
# top_k_index 25
# k 26
# top_k_index 26
# k 26
# top_k_index 26
# k 26
# top_k_index 26
# k 27
# top_k_index 27
# k 27
# top_k_index 27
# k 27
# top_k_index 27
# k 27
# top_k_index 27
# k 27
# top_k_index 27
# k 28
# top_k_index 28
# k 28
# top_k_index 28
# k 28
# top_k_index 28
# k 29
# top_k_index 29
# k 29
# top_k_index 29
# k 29
# top_k_index 29
# k 29
# top_k_index 29
# k 29
# top_k_index 29
# k 29
# top_k_index 29
# k 29
# top_k_index 29
# k 30
# top_k_index 30
# k 30
# top_k_index 30
# k 31
# top_k_index 31
# k 31
# top_k_index 31
# k 32
# top_k_index 32
# k 32
# top_k_index 32
# k 32
# top_k_index 32
# k 33
# top_k_index 33
# k 33
# top_k_index 33
# k 33
# top_k_index 33
# k 33
# top_k_index 33
# k 34
# top_k_index 34
# k 34
# top_k_index 34
# k 34
# top_k_index 34
# k 34
# top_k_index 34
# k 35
# top_k_index 35
# k 35
# top_k_index 35
# k 35
# top_k_index 35
# k 35
# top_k_index 35
# k 35
# top_k_index 35
# k 36
# top_k_index 36
# k 36
# top_k_index 36
# k 37
# top_k_index 37
# k 38
# top_k_index 38
# k 38
# top_k_index 38
# k 39
# top_k_index 39
# k 39
# top_k_index 39
# k 40
# top_k_index 40
# k 40
# top_k_index 40
# k 40
# top_k_index 40
# k 40
# top_k_index 40
# k 40
# top_k_index 40
# k 41
# top_k_index 41
# k 42
# top_k_index 42
# k 42
# top_k_index 42
# k 42
# top_k_index 42
# k 42
# top_k_index 42
# k 42
# top_k_index 42
# k 42
# top_k_index 42
# k 43
# top_k_index 43
# k 44
# top_k_index 44
# k 45
# top_k_index 45
# k 45
# top_k_index 45
# k 45
# top_k_index 45
# k 45
# top_k_index 45
# k 46
# top_k_index 46
# k 46
# top_k_index 46
# k 46
# top_k_index 46
# k 46
# top_k_index 46
# k 47
# top_k_index 47
# k 47
# top_k_index 47
# k 47
# top_k_index 47
# k 47
# top_k_index 47
# k 48
# top_k_index 48
# k 50
# top_k_index 50
# k 51
# top_k_index 51
# k 52
# top_k_index 52
# k 53
# top_k_index 53
# k 53
# top_k_index 53
# k 53
# top_k_index 53
# k 53
# top_k_index 53
# k 54
# top_k_index 54
# k 54
# top_k_index 54
# k 54
# top_k_index 54
# k 55
# top_k_index 55
# k 58
# top_k_index 58
# k 58
# top_k_index 58
# k 59
# top_k_index 59
# k 60
# top_k_index 60
# k 60
# top_k_index 60
# k 60
# top_k_index 60
# k 62
# top_k_index 62
# k 62
# top_k_index 62
# k 62
# top_k_index 62
# k 63
# top_k_index 63
# k 63
# top_k_index 63
# k 63
# top_k_index 63
# k 65
# top_k_index 65
# k 65
# top_k_index 65
# k 66
# top_k_index 66
# k 67
# top_k_index 67
# k 67
# top_k_index 67
# k 68
# top_k_index 68
# k 70
# top_k_index 70
# k 70
# top_k_index 70
# k 70
# top_k_index 70
# k 71
# top_k_index 71
# k 71
# top_k_index 71
# k 71
# top_k_index 71
# k 71
# top_k_index 71
# k 72
# top_k_index 72
# k 73
# top_k_index 73
# k 73
# top_k_index 73
# k 73
# top_k_index 73
# k 74
# top_k_index 74
# k 75
# top_k_index 75
# k 75
# top_k_index 75
# k 75
# top_k_index 75
# k 76
# top_k_index 76
# k 76
# top_k_index 76
# k 77
# top_k_index 77
# k 77
# top_k_index 77
# k 78
# top_k_index 78
# k 78
# top_k_index 78
# k 79
# top_k_index 79
# k 79
# top_k_index 79
# k 79
# top_k_index 79
# k 79
# top_k_index 79
# k 80
# top_k_index 80
# k 80
# top_k_index 80
# k 80
# top_k_index 80
# k 83
# top_k_index 83
# k 83
# top_k_index 83
# k 83
# top_k_index 83
# k 84
# top_k_index 84
# k 84
# top_k_index 84
# k 85
# top_k_index 85
# k 85
# top_k_index 85
# k 86
# top_k_index 86
# k 86
# top_k_index 86
# k 86
# top_k_index 86
# k 87
# top_k_index 87
# k 88
# top_k_index 88
# k 89
# top_k_index 89
# k 90
# top_k_index 90
# k 91
# top_k_index 91
# k 91
# top_k_index 91
# k 91
# top_k_index 91
# k 92
# top_k_index 92
# k 93
# top_k_index 93
# k 93
# top_k_index 93
# k 94
# top_k_index 94
# k 95
# top_k_index 95
# k 96
# top_k_index 96
# k 96
# top_k_index 96
# k 96
# top_k_index 96
# k 97
# top_k_index 97
# k 97
# top_k_index 97
# k 99
# top_k_index 99
# k 99
# top_k_index 99
# k 100
# top_k_index 100
# k 102
# top_k_index 102
# k 103
# top_k_index 103
# k 103
# top_k_index 103
# k 106
# top_k_index 106
# k 108
# top_k_index 108
# k 109
# top_k_index 109
# k 109
# top_k_index 109
# k 109
# top_k_index 109
# k 109
# top_k_index 109
# k 109
# top_k_index 109
# k 110
# top_k_index 110
# k 114
# top_k_index 114
# k 115
# top_k_index 115
# k 115
# top_k_index 115
# k 116
# top_k_index 116
# k 116
# top_k_index 116
# k 116
# top_k_index 116
# k 117
# top_k_index 117
# k 118
# top_k_index 118
# k 118
# top_k_index 118
# k 121
# top_k_index 121
# k 121
# top_k_index 121
# k 122
# top_k_index 122
# k 122
# top_k_index 122
# k 124
# top_k_index 124
# k 124
# top_k_index 124
# k 125
# top_k_index 125
# k 126
# top_k_index 126
# k 127
# top_k_index 127
# k 128
# top_k_index 128
# k 129
# top_k_index 129
# k 129
# top_k_index 129
# k 130
# top_k_index 130
# k 130
# top_k_index 130
# k 130
# top_k_index 130
# k 131
# top_k_index 131
# k 131
# top_k_index 131
# k 131
# top_k_index 131
# k 132
# top_k_index 132
# k 133
# top_k_index 133
# k 133
# top_k_index 133
# k 134
# top_k_index 134
# k 134
# top_k_index 134
# k 134
# top_k_index 134
# k 135
# top_k_index 135
# k 135
# top_k_index 135
# k 136
# top_k_index 136
# k 136
# top_k_index 136
# k 138
# top_k_index 138
# k 139
# top_k_index 139
# k 140
# top_k_index 140
# k 141
# top_k_index 141
# k 141
# top_k_index 141
# k 141
# top_k_index 141
# k 142
# top_k_index 142
# k 143
# top_k_index 143
# k 143
# top_k_index 143
# k 143
# top_k_index 143
# k 149
# top_k_index 149
# k 151
# top_k_index 151
# k 151
# top_k_index 151
# k 152
# top_k_index 152
# k 152
# top_k_index 152
# k 152
# top_k_index 152
# k 154
# top_k_index 154
# k 155
# top_k_index 155
# k 155
# top_k_index 155
# k 156
# top_k_index 156
# k 156
# top_k_index 156
# k 157
# top_k_index 157
# k 157
# top_k_index 157
# k 157
# top_k_index 157
# k 158
# top_k_index 158
# k 158
# top_k_index 158
# k 158
# top_k_index 158
# k 160
# top_k_index 160
# k 161
# top_k_index 161
# k 162
# top_k_index 162
# k 162
# top_k_index 162
# k 162
# top_k_index 162
# k 162
# top_k_index 162
# k 164
# top_k_index 164
# k 165
# top_k_index 165
# k 166
# top_k_index 166
# k 166
# top_k_index 166
# k 167
# top_k_index 167
# k 168
# top_k_index 168
# k 170
# top_k_index 170
# k 172
# top_k_index 172
# k 174
# top_k_index 174
# k 177
# top_k_index 177
# k 178
# top_k_index 178
# k 179
# top_k_index 179
# k 181
# top_k_index 181
# k 181
# top_k_index 181
# k 182
# top_k_index 182
# k 183
# top_k_index 183
# k 184
# top_k_index 184
# k 184
# top_k_index 184
# k 184
# top_k_index 184
# k 186
# top_k_index 186
# k 187
# top_k_index 187
# k 189
# top_k_index 189
# k 189
# top_k_index 189
# k 190
# top_k_index 190
# k 192
# top_k_index 192
# k 196
# top_k_index 196
# k 196
# top_k_index 196
# k 198
# top_k_index 198
# k 198
# top_k_index 198
# k 198
# top_k_index 198
# k 199
# top_k_index 199
# k 201
# top_k_index 201
# k 204
# top_k_index 204
# k 204
# top_k_index 204
# k 205
# top_k_index 205
# k 208
# top_k_index 208
# k 210
# top_k_index 210
# k 213
# top_k_index 213
# k 213
# top_k_index 213
# k 214
# top_k_index 214
# k 215
# top_k_index 215
# k 220
# top_k_index 220
# k 221
# top_k_index 221
# k 222
# top_k_index 222
# k 222
# top_k_index 222
# k 223
# top_k_index 223
# k 224
# top_k_index 224
# k 224
# top_k_index 224
# k 225
# top_k_index 225
# k 225
# top_k_index 225
# k 226
# top_k_index 226
# k 227
# top_k_index 227
# k 229
# top_k_index 229
# k 229
# top_k_index 229
# k 231
# top_k_index 231
# k 235
# top_k_index 235
# k 238
# top_k_index 238
# k 239
# top_k_index 239
# k 240
# top_k_index 240
# k 240
# top_k_index 240
# k 241
# top_k_index 241
# k 241
# top_k_index 241
# k 243
# top_k_index 243
# k 244
# top_k_index 244
# k 244
# top_k_index 244
# k 246
# top_k_index 246
# k 247
# top_k_index 247
# k 248
# top_k_index 248
# k 248
# top_k_index 248
# k 251
# top_k_index 251
# k 252
# top_k_index 252
# k 252
# top_k_index 252
# k 254
# top_k_index 254
# k 255
# top_k_index 255
# k 257
# top_k_index 257
# k 257
# top_k_index 257
# k 260
# top_k_index 260
# k 261
# top_k_index 261
# k 268
# top_k_index 268
# k 269
# top_k_index 269
# k 271
# top_k_index 271
# k 271
# top_k_index 271
# k 271
# top_k_index 271
# k 271
# top_k_index 271
# k 271
# top_k_index 271
# k 274
# top_k_index 274
# k 274
# top_k_index 274
# k 274
# top_k_index 274
# k 274
# top_k_index 274
# k 275
# top_k_index 275
# k 278
# top_k_index 278
# k 279
# top_k_index 279
# k 279
# top_k_index 279
# k 283
# top_k_index 283
# k 283
# top_k_index 283
# k 285
# top_k_index 285
# k 286
# top_k_index 286
# k 288
# top_k_index 288
# k 289
# top_k_index 289
# k 291
# top_k_index 291
# k 293
# top_k_index 293
# k 295
# top_k_index 295
# k 295
# top_k_index 295
# k 297
# top_k_index 297
# k 298
# top_k_index 298
# k 299
# top_k_index 299
# k 301
# top_k_index 301
# k 302
# top_k_index 302
# k 306
# top_k_index 306
# k 313
# top_k_index 313
# k 313
# top_k_index 313
# k 315
# top_k_index 315
# k 316
# top_k_index 316
# k 317
# top_k_index 317
# k 318
# top_k_index 318
# k 318
# top_k_index 318
# k 323
# top_k_index 323
# k 323
# top_k_index 323
# k 324
# top_k_index 324
# k 325
# top_k_index 325
# k 326
# top_k_index 326
# k 328
# top_k_index 328
# k 332
# top_k_index 332
# k 333
# top_k_index 333
# k 336
# top_k_index 336
# k 336
# top_k_index 336
# k 338
# top_k_index 338
# k 339
# top_k_index 339
# k 344
# top_k_index 344
# k 346
# top_k_index 346
# k 347
# top_k_index 347
# k 348
# top_k_index 348
# k 349
# top_k_index 349
# k 349
# top_k_index 349
# k 351
# top_k_index 351
# k 352
# top_k_index 352
# k 352
# top_k_index 352
# k 354
# top_k_index 354
# k 356
# top_k_index 356
# k 356
# top_k_index 356
# k 356
# top_k_index 356
# k 360
# top_k_index 360
# k 361
# top_k_index 361
# k 362
# top_k_index 362
# k 364
# top_k_index 364
# k 364
# top_k_index 364
# k 369
# top_k_index 369
# k 370
# top_k_index 370
# k 370
# top_k_index 370
# k 372
# top_k_index 372
# k 375
# top_k_index 375
# k 376
# top_k_index 376
# k 384
# top_k_index 384
# k 386
# top_k_index 386
# k 388
# top_k_index 388
# k 392
# top_k_index 392
# k 393
# top_k_index 393
# k 397
# top_k_index 397
# k 399
# top_k_index 399
# k 400
# top_k_index 400
# k 400
# top_k_index 400
# k 401
# top_k_index 401
# k 402
# top_k_index 402
# k 403
# top_k_index 403
# k 404
# top_k_index 404
# k 404
# top_k_index 404
# k 406
# top_k_index 406
# k 407
# top_k_index 407
# k 418
# top_k_index 418
# k 420
# top_k_index 420
# k 420
# top_k_index 420
# k 421
# top_k_index 421
# k 421
# top_k_index 421
# k 423
# top_k_index 423
# k 423
# top_k_index 423
# k 429
# top_k_index 429
# k 439
# top_k_index 439
# k 447
# top_k_index 447
# k 448
# top_k_index 448
# k 453
# top_k_index 453
# k 455
# top_k_index 455
# k 458
# top_k_index 458
# k 460
# top_k_index 460
# k 460
# top_k_index 460
# k 460
# top_k_index 460
# k 461
# top_k_index 461
# k 465
# top_k_index 465
# k 470
# top_k_index 470
# k 483
# top_k_index 483
# k 488
# top_k_index 488
# k 493
# top_k_index 493
# k 509
# top_k_index 509
# k 510
# top_k_index 510
# k 511
# top_k_index 511
# k 512
# top_k_index 512
# k 512
# top_k_index 512
# k 516
# top_k_index 516
# k 518
# top_k_index 518
# k 518
# top_k_index 518
# k 518
# top_k_index 518
# k 519
# top_k_index 519
# k 520
# top_k_index 520
# k 527
# top_k_index 527
# k 531
# top_k_index 531
# k 540
# top_k_index 540
# k 541
# top_k_index 541
# k 550
# top_k_index 550
# k 551
# top_k_index 551
# k 558
# top_k_index 558
# k 564
# top_k_index 564
# k 569
# top_k_index 569
# k 570
# top_k_index 570
# k 572
# top_k_index 572
# k 575
# top_k_index 575
# k 575
# top_k_index 575
# k 577
# top_k_index 577
# k 579
# top_k_index 579
# k 579
# top_k_index 579
# k 582
# top_k_index 582
# k 583
# top_k_index 583
# k 588
# top_k_index 588
# k 594
# top_k_index 594
# k 594
# top_k_index 594
# k 604
# top_k_index 604
# k 605
# top_k_index 605
# k 627
# top_k_index 627
# k 628
# top_k_index 628
# k 628
# top_k_index 628
# k 629
# top_k_index 629
# k 630
# top_k_index 630
# k 630
# top_k_index 630
# k 637
# top_k_index 637
# k 637
# top_k_index 637
# k 641
# top_k_index 641
# k 655
# top_k_index 655
# k 669
# top_k_index 669
# k 670
# top_k_index 670
# k 670
# top_k_index 670
# k 675
# top_k_index 675
# k 678
# top_k_index 678
# k 681
# top_k_index 681
# k 684
# top_k_index 684
# k 690
# top_k_index 690
# k 698
# top_k_index 698
# k 708
# top_k_index 708
# k 708
# top_k_index 708
# k 718
# top_k_index 718
# k 730
# top_k_index 730
# k 738
# top_k_index 738
# k 741
# top_k_index 741
# k 742
# top_k_index 742
# k 743
# top_k_index 743
# k 744
# top_k_index 744
# k 747
# top_k_index 747
# k 751
# top_k_index 751
# k 758
# top_k_index 758
# k 762
# top_k_index 762
# k 773
# top_k_index 773
# k 773
# top_k_index 773
# k 778
# top_k_index 778
# k 779
# top_k_index 779
# k 780
# top_k_index 780
# k 782
# top_k_index 782
# k 788
# top_k_index 788
# k 804
# top_k_index 804
# k 812
# top_k_index 812
# k 820
# top_k_index 820
# k 829
# top_k_index 829
# k 834
# top_k_index 834
# k 838
# top_k_index 838
# k 838
# top_k_index 838
# k 853
# top_k_index 853
# k 858
# top_k_index 858
# k 862
# top_k_index 862
# k 863
# top_k_index 863
# k 864
# top_k_index 864
# k 868
# top_k_index 868
# k 879
# top_k_index 879
# k 879
# top_k_index 879
# k 879
# top_k_index 879
# k 893
# top_k_index 893
# k 895
# top_k_index 895
# k 907
# top_k_index 907
# k 924
# top_k_index 924
# k 925
# top_k_index 925
# k 940
# top_k_index 940
# k 946
# top_k_index 946
# k 949
# top_k_index 949
# k 954
# top_k_index 954
# k 955
# top_k_index 955
# k 963
# top_k_index 963
# k 970
# top_k_index 970
# k 975
# top_k_index 975
# k 978
# top_k_index 978
# k 984
# top_k_index 984
# k 993
# top_k_index 993
# k 1001
# top_k_index 1001
# k 1001
# top_k_index 1001
# k 1002
# top_k_index 1002
# k 1003
# top_k_index 1003
# k 1006
# top_k_index 1006
# k 1009
# top_k_index 1009
# k 1012
# top_k_index 1012
# k 1016
# top_k_index 1016
# k 1016
# top_k_index 1016
# k 1028
# top_k_index 1028
# k 1034
# top_k_index 1034
# k 1062
# top_k_index 1062
# k 1064
# top_k_index 1064
# k 1076
# top_k_index 1076
# k 1084
# top_k_index 1084
# k 1094
# top_k_index 1094
# k 1103
# top_k_index 1103
# k 1112
# top_k_index 1112
# k 1116
# top_k_index 1116
# k 1140
# top_k_index 1140
# k 1163
# top_k_index 1163
# k 1169
# top_k_index 1169
# k 1169
# top_k_index 1169
# k 1182
# top_k_index 1182
# k 1184
# top_k_index 1184
# k 1194
# top_k_index 1194
# k 1212
# top_k_index 1212
# k 1221
# top_k_index 1221
# k 1236
# top_k_index 1236
# k 1236
# top_k_index 1236
# k 1238
# top_k_index 1238
# k 1242
# top_k_index 1242
# k 1255
# top_k_index 1255
# k 1263
# top_k_index 1263
# k 1275
# top_k_index 1275
# k 1311
# top_k_index 1311
# k 1313
# top_k_index 1313
# k 1328
# top_k_index 1328
# k 1342
# top_k_index 1342
# k 1347
# top_k_index 1347
# k 1348
# top_k_index 1348
# k 1396
# top_k_index 1396
# k 1439
# top_k_index 1439
# k 1496
# top_k_index 1496
# k 3572
# top_k_index 3572

# %%
import csv

with open('CSV_SST_bertlin_alg4.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the header
    writer.writerow(header)

    # write multiple rows
    writer.writerows(data)

# %%
ls
# Out:
# CSV_SST_LR_alg4.csv                    diffs_SST_LR_I100_D1_.npy
# CSV_SST_LR_alg4.ipynb                  diffs_SST_bertT_I100_D1.npy
# CSV_SST_bertlin_alg4.csv               iterations_SST_LR_I100_D1.npy
# CSV_SST_bertlin_alg4.ipynb             iterations_SST_LR_I100_D1_.npy
# CSV_emo_LR_alg4.ipynb                  iterations_SST_bertT_I100_D1.npy
# NT_app_k_SST_LR_I100_D1.npy            new_predictions_SST_LR_I100_D1.npy
# NT_app_k_SST_LR_I100_D1_.npy           new_predictions_SST_LR_I100_D1_.npy
# NT_app_k_SST_bertT_I100_D1.npy         new_predictions_SST_bertT_I100_D1.npy
# Recursive_IP.py                        order_SST_LR_I100_D1.npy
# Recursive_IP_emotion.ipynb             order_SST_LR_I100_D1_.npy
# Recursive_IP_sst.ipynb                 order_SST_bertT_I100_D1.npy
# SST_LR.ipynb                           test_feature_SST.npy
# SST_bertlin.ipynb                      test_label_SST.npy
# Untitled.ipynb                         train_feature_SST.npy
# diffs_SST_LR_I100_D1.npy               train_label_SST.npy

# %%
pwd
# Out:
# '/Users/eciel/Desktop/y3s2_sum/orf/summer/privacy_methods/LR/IF+Newton/Server_all_experiments/recursive_all/SST'
